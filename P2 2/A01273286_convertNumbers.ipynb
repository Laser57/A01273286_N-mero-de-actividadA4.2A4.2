# %%
import time
import pylint
#Linea para derterminar inicio de tiempo
TIEMPO_INICIO = time.time()
MASTER = []
NUMEROS = ['1', '2', '3', '4', '5', '6', '7', '8', '9', '0', '-', '.', ',']
with open('TC3.txt', 'r', encoding='UTF-8') as file:
    for linea in file:
        AUX = ""
        for i in linea.strip():
            if i in NUMEROS:
                AUX += i
            else:
                break
        MASTER.append(int(AUX))
LISTA_BINARIA=[]
for NUMERO in MASTER:
    BINARIO=""
    NEGATIVO=False
    if NUMERO<0:
        NEGATIVO=True
        NUMERO=abs(NUMERO)
    while NUMERO > 0:
        RESIDUO = NUMERO % 2
        BINARIO = str(RESIDUO) + BINARIO
        NUMERO //= 2
    if NEGATIVO:
        BINARIO=BINARIO.zfill(8)
        BINARIO="".join('1' if BIT == '0' else '0' for BIT in str(BINARIO))
        COMPLEMENTO = "00000001"
        RESULTADO = ""
        ACARREO = 0
        for i in range(8 - 1, -1, -1):
            BIT1 = int(BINARIO[i])
            BIT2 = int(COMPLEMENTO[i])
            SUMA_BIT = BIT1 + BIT2 + ACARREO
            RESULTADO = str(SUMA_BIT % 2) + RESULTADO
            ACARREO = SUMA_BIT // 2
        if ACARREO:
            RESULTADO = "1" + RESULTADO
        LISTA_BINARIA.append(RESULTADO)
    else:
        LISTA_BINARIA.append(BINARIO)
LISTA_HEXADECIMAL=[]
for NUMERO in MASTER:
    HEX=""
    if NUMERO < 0:
        NUMERO = 2**32 + NUMERO
    while NUMERO > 0:
        RESIDUO = NUMERO % 16
        if RESIDUO>=10:
            RESIDUO=chr(ord('A') + RESIDUO - 10)
        HEX = str(RESIDUO) + HEX
        NUMERO //= 16
    LISTA_HEXADECIMAL.append(HEX)

for i in range(len(MASTER)):
    print(f"DECIMAL: {MASTER[i]} BINARIO: {LISTA_BINARIA[i]} HEXADECIMAL: {LISTA_HEXADECIMAL[i]}")
#Tiempo final
TIEMPO_FINAL = time.time() - TIEMPO_INICIO
print(f"Tiempo de ejecución: {TIEMPO_FINAL} segundos")
# Out:
# DECIMAL: -39 BINARIO: 11011001 HEXADECIMAL: FFFFFFD9
# DECIMAL: -36 BINARIO: 11011100 HEXADECIMAL: FFFFFFDC
# DECIMAL: 8 BINARIO: 1000 HEXADECIMAL: 8
# DECIMAL: 34 BINARIO: 100010 HEXADECIMAL: 22
# DECIMAL: 17 BINARIO: 10001 HEXADECIMAL: 11
# DECIMAL: 49 BINARIO: 110001 HEXADECIMAL: 31
# DECIMAL: 5 BINARIO: 101 HEXADECIMAL: 5
# DECIMAL: 39 BINARIO: 100111 HEXADECIMAL: 27
# DECIMAL: 0 BINARIO:  HEXADECIMAL:
# DECIMAL: 33 BINARIO: 100001 HEXADECIMAL: 21
# DECIMAL: 12 BINARIO: 1100 HEXADECIMAL: C
# DECIMAL: -6 BINARIO: 11111010 HEXADECIMAL: FFFFFFFA
# DECIMAL: 27 BINARIO: 11011 HEXADECIMAL: 1B
# DECIMAL: -4 BINARIO: 11111100 HEXADECIMAL: FFFFFFFC
# DECIMAL: -38 BINARIO: 11011010 HEXADECIMAL: FFFFFFDA
# DECIMAL: 26 BINARIO: 11010 HEXADECIMAL: 1A
# DECIMAL: 49 BINARIO: 110001 HEXADECIMAL: 31
# DECIMAL: 29 BINARIO: 11101 HEXADECIMAL: 1D
# DECIMAL: 42 BINARIO: 101010 HEXADECIMAL: 2A
# DECIMAL: -16 BINARIO: 11110000 HEXADECIMAL: FFFFFFF0
# DECIMAL: -28 BINARIO: 11100100 HEXADECIMAL: FFFFFFE4
# DECIMAL: 34 BINARIO: 100010 HEXADECIMAL: 22
# DECIMAL: 20 BINARIO: 10100 HEXADECIMAL: 14
# DECIMAL: 0 BINARIO:  HEXADECIMAL:
# DECIMAL: 25 BINARIO: 11001 HEXADECIMAL: 19
# DECIMAL: 45 BINARIO: 101101 HEXADECIMAL: 2D
# DECIMAL: 3 BINARIO: 11 HEXADECIMAL: 3
# DECIMAL: -46 BINARIO: 11010010 HEXADECIMAL: FFFFFFD2
# DECIMAL: -46 BINARIO: 11010010 HEXADECIMAL: FFFFFFD2
# DECIMAL: 29 BINARIO: 11101 HEXADECIMAL: 1D
# DECIMAL: 33 BINARIO: 100001 HEXADECIMAL: 21
# DECIMAL: 29 BINARIO: 11101 HEXADECIMAL: 1D
# DECIMAL: 26 BINARIO: 11010 HEXADECIMAL: 1A
# DECIMAL: -5 BINARIO: 11111011 HEXADECIMAL: FFFFFFFB
# DECIMAL: -36 BINARIO: 11011100 HEXADECIMAL: FFFFFFDC
# DECIMAL: 12 BINARIO: 1100 HEXADECIMAL: C
# DECIMAL: 45 BINARIO: 101101 HEXADECIMAL: 2D
# DECIMAL: -50 BINARIO: 11001110 HEXADECIMAL: FFFFFFCE
# DECIMAL: 0 BINARIO:  HEXADECIMAL:
# DECIMAL: -6 BINARIO: 11111010 HEXADECIMAL: FFFFFFFA
# DECIMAL: -39 BINARIO: 11011001 HEXADECIMAL: FFFFFFD9
# DECIMAL: 35 BINARIO: 100011 HEXADECIMAL: 23
# DECIMAL: 26 BINARIO: 11010 HEXADECIMAL: 1A
# DECIMAL: -35 BINARIO: 11011101 HEXADECIMAL: FFFFFFDD
# DECIMAL: -42 BINARIO: 11010110 HEXADECIMAL: FFFFFFD6
# DECIMAL: 14 BINARIO: 1110 HEXADECIMAL: E
# DECIMAL: -3 BINARIO: 11111101 HEXADECIMAL: FFFFFFFD
# DECIMAL: 22 BINARIO: 10110 HEXADECIMAL: 16
# DECIMAL: -47 BINARIO: 11010001 HEXADECIMAL: FFFFFFD1
# DECIMAL: 12 BINARIO: 1100 HEXADECIMAL: C
# DECIMAL: -17 BINARIO: 11101111 HEXADECIMAL: FFFFFFEF
# DECIMAL: -31 BINARIO: 11100001 HEXADECIMAL: FFFFFFE1
# DECIMAL: -25 BINARIO: 11100111 HEXADECIMAL: FFFFFFE7
# DECIMAL: -35 BINARIO: 11011101 HEXADECIMAL: FFFFFFDD
# DECIMAL: -18 BINARIO: 11101110 HEXADECIMAL: FFFFFFEE
# DECIMAL: 14 BINARIO: 1110 HEXADECIMAL: E
# DECIMAL: 37 BINARIO: 100101 HEXADECIMAL: 25
# DECIMAL: -8 BINARIO: 11111000 HEXADECIMAL: FFFFFFF8
# DECIMAL: -41 BINARIO: 11010111 HEXADECIMAL: FFFFFFD7
# DECIMAL: -50 BINARIO: 11001110 HEXADECIMAL: FFFFFFCE
# DECIMAL: -9 BINARIO: 11110111 HEXADECIMAL: FFFFFFF7
# DECIMAL: 2 BINARIO: 10 HEXADECIMAL: 2
# DECIMAL: 12 BINARIO: 1100 HEXADECIMAL: C
# DECIMAL: -39 BINARIO: 11011001 HEXADECIMAL: FFFFFFD9
# DECIMAL: -17 BINARIO: 11101111 HEXADECIMAL: FFFFFFEF
# DECIMAL: 0 BINARIO:  HEXADECIMAL:
# DECIMAL: 27 BINARIO: 11011 HEXADECIMAL: 1B
# DECIMAL: 28 BINARIO: 11100 HEXADECIMAL: 1C
# DECIMAL: 45 BINARIO: 101101 HEXADECIMAL: 2D
# DECIMAL: -44 BINARIO: 11010100 HEXADECIMAL: FFFFFFD4
# DECIMAL: 28 BINARIO: 11100 HEXADECIMAL: 1C
# DECIMAL: 35 BINARIO: 100011 HEXADECIMAL: 23
# DECIMAL: -33 BINARIO: 11011111 HEXADECIMAL: FFFFFFDF
# DECIMAL: 43 BINARIO: 101011 HEXADECIMAL: 2B
# DECIMAL: -4 BINARIO: 11111100 HEXADECIMAL: FFFFFFFC
# DECIMAL: 23 BINARIO: 10111 HEXADECIMAL: 17
# DECIMAL: -49 BINARIO: 11001111 HEXADECIMAL: FFFFFFCF
# DECIMAL: 49 BINARIO: 110001 HEXADECIMAL: 31
# DECIMAL: -7 BINARIO: 11111001 HEXADECIMAL: FFFFFFF9
# DECIMAL: -38 BINARIO: 11011010 HEXADECIMAL: FFFFFFDA
# DECIMAL: -45 BINARIO: 11010011 HEXADECIMAL: FFFFFFD3
# DECIMAL: 5 BINARIO: 101 HEXADECIMAL: 5
# DECIMAL: -21 BINARIO: 11101011 HEXADECIMAL: FFFFFFEB
# DECIMAL: 26 BINARIO: 11010 HEXADECIMAL: 1A
# DECIMAL: -2 BINARIO: 11111110 HEXADECIMAL: FFFFFFFE
# DECIMAL: -24 BINARIO: 11101000 HEXADECIMAL: FFFFFFE8
# DECIMAL: 6 BINARIO: 110 HEXADECIMAL: 6
# DECIMAL: -45 BINARIO: 11010011 HEXADECIMAL: FFFFFFD3
# DECIMAL: -4 BINARIO: 11111100 HEXADECIMAL: FFFFFFFC
# DECIMAL: 15 BINARIO: 1111 HEXADECIMAL: F
# DECIMAL: 0 BINARIO:  HEXADECIMAL:
# DECIMAL: -17 BINARIO: 11101111 HEXADECIMAL: FFFFFFEF
# DECIMAL: -35 BINARIO: 11011101 HEXADECIMAL: FFFFFFDD
# DECIMAL: 43 BINARIO: 101011 HEXADECIMAL: 2B
# DECIMAL: 45 BINARIO: 101101 HEXADECIMAL: 2D
# DECIMAL: -35 BINARIO: 11011101 HEXADECIMAL: FFFFFFDD
# DECIMAL: -8 BINARIO: 11111000 HEXADECIMAL: FFFFFFF8
# DECIMAL: 28 BINARIO: 11100 HEXADECIMAL: 1C
# DECIMAL: 47 BINARIO: 101111 HEXADECIMAL: 2F
# DECIMAL: 34 BINARIO: 100010 HEXADECIMAL: 22
# DECIMAL: -24 BINARIO: 11101000 HEXADECIMAL: FFFFFFE8
# DECIMAL: -42 BINARIO: 11010110 HEXADECIMAL: FFFFFFD6
# DECIMAL: -13 BINARIO: 11110011 HEXADECIMAL: FFFFFFF3
# DECIMAL: 14 BINARIO: 1110 HEXADECIMAL: E
# DECIMAL: -45 BINARIO: 11010011 HEXADECIMAL: FFFFFFD3
# DECIMAL: -35 BINARIO: 11011101 HEXADECIMAL: FFFFFFDD
# DECIMAL: 27 BINARIO: 11011 HEXADECIMAL: 1B
# DECIMAL: -12 BINARIO: 11110100 HEXADECIMAL: FFFFFFF4
# DECIMAL: -19 BINARIO: 11101101 HEXADECIMAL: FFFFFFED
# DECIMAL: -20 BINARIO: 11101100 HEXADECIMAL: FFFFFFEC
# DECIMAL: -14 BINARIO: 11110010 HEXADECIMAL: FFFFFFF2
# DECIMAL: 20 BINARIO: 10100 HEXADECIMAL: 14
# DECIMAL: 30 BINARIO: 11110 HEXADECIMAL: 1E
# DECIMAL: 12 BINARIO: 1100 HEXADECIMAL: C
# DECIMAL: -36 BINARIO: 11011100 HEXADECIMAL: FFFFFFDC
# DECIMAL: -47 BINARIO: 11010001 HEXADECIMAL: FFFFFFD1
# DECIMAL: -27 BINARIO: 11100101 HEXADECIMAL: FFFFFFE5
# DECIMAL: -3 BINARIO: 11111101 HEXADECIMAL: FFFFFFFD
# DECIMAL: 6 BINARIO: 110 HEXADECIMAL: 6
# DECIMAL: 36 BINARIO: 100100 HEXADECIMAL: 24
# DECIMAL: 9 BINARIO: 1001 HEXADECIMAL: 9
# DECIMAL: -16 BINARIO: 11110000 HEXADECIMAL: FFFFFFF0
# DECIMAL: 36 BINARIO: 100100 HEXADECIMAL: 24
# DECIMAL: -27 BINARIO: 11100101 HEXADECIMAL: FFFFFFE5
# DECIMAL: 7 BINARIO: 111 HEXADECIMAL: 7
# DECIMAL: -6 BINARIO: 11111010 HEXADECIMAL: FFFFFFFA
# DECIMAL: -5 BINARIO: 11111011 HEXADECIMAL: FFFFFFFB
# DECIMAL: 5 BINARIO: 101 HEXADECIMAL: 5
# DECIMAL: 47 BINARIO: 101111 HEXADECIMAL: 2F
# DECIMAL: 23 BINARIO: 10111 HEXADECIMAL: 17
# DECIMAL: -48 BINARIO: 11010000 HEXADECIMAL: FFFFFFD0
# DECIMAL: -24 BINARIO: 11101000 HEXADECIMAL: FFFFFFE8
# DECIMAL: 40 BINARIO: 101000 HEXADECIMAL: 28
# DECIMAL: -4 BINARIO: 11111100 HEXADECIMAL: FFFFFFFC
# DECIMAL: -18 BINARIO: 11101110 HEXADECIMAL: FFFFFFEE
# DECIMAL: -19 BINARIO: 11101101 HEXADECIMAL: FFFFFFED
# DECIMAL: 14 BINARIO: 1110 HEXADECIMAL: E
# DECIMAL: 15 BINARIO: 1111 HEXADECIMAL: F
# DECIMAL: 1 BINARIO: 1 HEXADECIMAL: 1
# DECIMAL: 24 BINARIO: 11000 HEXADECIMAL: 18
# DECIMAL: -9 BINARIO: 11110111 HEXADECIMAL: FFFFFFF7
# DECIMAL: -50 BINARIO: 11001110 HEXADECIMAL: FFFFFFCE
# DECIMAL: 18 BINARIO: 10010 HEXADECIMAL: 12
# DECIMAL: 15 BINARIO: 1111 HEXADECIMAL: F
# DECIMAL: 30 BINARIO: 11110 HEXADECIMAL: 1E
# DECIMAL: 44 BINARIO: 101100 HEXADECIMAL: 2C
# DECIMAL: 9 BINARIO: 1001 HEXADECIMAL: 9
# DECIMAL: 19 BINARIO: 10011 HEXADECIMAL: 13
# DECIMAL: 33 BINARIO: 100001 HEXADECIMAL: 21
# DECIMAL: 41 BINARIO: 101001 HEXADECIMAL: 29
# DECIMAL: -24 BINARIO: 11101000 HEXADECIMAL: FFFFFFE8
# DECIMAL: 43 BINARIO: 101011 HEXADECIMAL: 2B
# DECIMAL: 48 BINARIO: 110000 HEXADECIMAL: 30
# DECIMAL: -23 BINARIO: 11101001 HEXADECIMAL: FFFFFFE9
# DECIMAL: 7 BINARIO: 111 HEXADECIMAL: 7
# DECIMAL: 28 BINARIO: 11100 HEXADECIMAL: 1C
# DECIMAL: 8 BINARIO: 1000 HEXADECIMAL: 8
# DECIMAL: -2 BINARIO: 11111110 HEXADECIMAL: FFFFFFFE
# DECIMAL: 37 BINARIO: 100101 HEXADECIMAL: 25
# DECIMAL: 42 BINARIO: 101010 HEXADECIMAL: 2A
# DECIMAL: -17 BINARIO: 11101111 HEXADECIMAL: FFFFFFEF
# DECIMAL: -6 BINARIO: 11111010 HEXADECIMAL: FFFFFFFA
# DECIMAL: 36 BINARIO: 100100 HEXADECIMAL: 24
# DECIMAL: 22 BINARIO: 10110 HEXADECIMAL: 16
# DECIMAL: 27 BINARIO: 11011 HEXADECIMAL: 1B
# DECIMAL: 31 BINARIO: 11111 HEXADECIMAL: 1F
# DECIMAL: -47 BINARIO: 11010001 HEXADECIMAL: FFFFFFD1
# DECIMAL: -43 BINARIO: 11010101 HEXADECIMAL: FFFFFFD5
# DECIMAL: 0 BINARIO:  HEXADECIMAL:
# DECIMAL: 27 BINARIO: 11011 HEXADECIMAL: 1B
# DECIMAL: 30 BINARIO: 11110 HEXADECIMAL: 1E
# DECIMAL: 12 BINARIO: 1100 HEXADECIMAL: C
# DECIMAL: -15 BINARIO: 11110001 HEXADECIMAL: FFFFFFF1
# DECIMAL: -19 BINARIO: 11101101 HEXADECIMAL: FFFFFFED
# DECIMAL: -42 BINARIO: 11010110 HEXADECIMAL: FFFFFFD6
# DECIMAL: -37 BINARIO: 11011011 HEXADECIMAL: FFFFFFDB
# DECIMAL: 31 BINARIO: 11111 HEXADECIMAL: 1F
# DECIMAL: -10 BINARIO: 11110110 HEXADECIMAL: FFFFFFF6
# DECIMAL: 18 BINARIO: 10010 HEXADECIMAL: 12
# DECIMAL: 33 BINARIO: 100001 HEXADECIMAL: 21
# DECIMAL: -15 BINARIO: 11110001 HEXADECIMAL: FFFFFFF1
# DECIMAL: 17 BINARIO: 10001 HEXADECIMAL: 11
# DECIMAL: 25 BINARIO: 11001 HEXADECIMAL: 19
# DECIMAL: -25 BINARIO: 11100111 HEXADECIMAL: FFFFFFE7
# DECIMAL: -5 BINARIO: 11111011 HEXADECIMAL: FFFFFFFB
# DECIMAL: 33 BINARIO: 100001 HEXADECIMAL: 21
# DECIMAL: -13 BINARIO: 11110011 HEXADECIMAL: FFFFFFF3
# DECIMAL: 33 BINARIO: 100001 HEXADECIMAL: 21
# DECIMAL: -10 BINARIO: 11110110 HEXADECIMAL: FFFFFFF6
# DECIMAL: 47 BINARIO: 101111 HEXADECIMAL: 2F
# DECIMAL: 47 BINARIO: 101111 HEXADECIMAL: 2F
# DECIMAL: -13 BINARIO: 11110011 HEXADECIMAL: FFFFFFF3
# DECIMAL: -32 BINARIO: 11100000 HEXADECIMAL: FFFFFFE0
# DECIMAL: 1 BINARIO: 1 HEXADECIMAL: 1
# DECIMAL: 1 BINARIO: 1 HEXADECIMAL: 1
# DECIMAL: -25 BINARIO: 11100111 HEXADECIMAL: FFFFFFE7
# DECIMAL: -33 BINARIO: 11011111 HEXADECIMAL: FFFFFFDF
# DECIMAL: 16 BINARIO: 10000 HEXADECIMAL: 10
# DECIMAL: 17 BINARIO: 10001 HEXADECIMAL: 11
# DECIMAL: 4 BINARIO: 100 HEXADECIMAL: 4
# Tiempo de ejecución: 0.006681203842163086 segundos
